# %% [markdown]
# # Fine-tune Bart on CNN/Daily

# %% [markdown]
# ## Libraries and environment preparation

# %%
#Install essential packages
# %%capture
# !pip install datasets transformers rouge-score nltk wandb
# !apt install git-lfs

# %%
#Colab Environment Check for GPU and RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

#GPU check
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Wed Feb 16 18:43:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Make sure your version of Transformers is at least 4.11.0 since the functionality was introduced in that version:

# %%
# Make sure your version of Transformers is at least 4.11.0 
# to run the following code correctly:
import datasets
import transformers
print(transformers.__version__)
# Out:
# 4.16.2

# %%
from transformers import AutoTokenizer    
# Huggingface Automodel class
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

model_checkpoint = "facebook/bart-base"

# %%
# Import Wandb 
import os
import wandb
API_KEY = '39991c538626bee25c64d4f8a4c3403dd635537c'
os.environ["WANDB_API_KEY"] = API_KEY

# %% [markdown]
# ## Loading the dataset

# %%
# import dataset
raw_datasets = datasets.load_dataset("ccdv/cnn_dailymail", "3.0.0")
# Out:
# Downloading:   0%|          | 0.00/9.27k [00:00<?, ?B/s]
# Downloading and preparing dataset cnn_dailymail/3.0.0 to /root/.cache/huggingface/datasets/ccdv___cnn_dailymail/3.0.0/3.0.0/0107f7388b5c6fae455a5661bcd134fc22da53ea75852027040d8d1e997f101f...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/159M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376M [00:00<?, ?B/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset cnn_dailymail downloaded and prepared to /root/.cache/huggingface/datasets/ccdv___cnn_dailymail/3.0.0/3.0.0/0107f7388b5c6fae455a5661bcd134fc22da53ea75852027040d8d1e997f101f. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['article', 'highlights', 'id'],
#         num_rows: 287113
#     })
#     validation: Dataset({
#         features: ['article', 'highlights', 'id'],
#         num_rows: 13368
#     })
#     test: Dataset({
#         features: ['article', 'highlights', 'id'],
#         num_rows: 11490
#     })
# })

# %% [markdown]
# ## Preprocessing the data

# %%
# Import tokenizer from model checkpoint
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
# tokenlize inputs into map

max_input_length = 1024
max_target_length = 128

def preprocess_function(examples):
    inputs = [doc for doc in examples["article"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["highlights"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = raw_datasets.map(preprocess_function, 
                                      batched=True,
                                      remove_columns=["id", "article", "highlights"])
# Out:
#   0%|          | 0/288 [00:00<?, ?ba/s]
#   0%|          | 0/14 [00:00<?, ?ba/s]
#   0%|          | 0/12 [00:00<?, ?ba/s]

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 287113
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 13368
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 11490
#     })
# })

# %% [markdown]
# ## Fine-tuning the model

# %%
# Import tokenizer from model checkpoint and print detail
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/532M [00:00<?, ?B/s]

# %%
# data collator: pad the inputs and labels during each batch to save space
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
# keep track with wandb
wandb.init(project="BART")
# Out:
# wandb: Currently logged in as: shusunny (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/shusunny/BART/runs/1v8evflt" target="_blank">sweet-fire-2</a></strong> to <a href="https://wandb.ai/shusunny/BART" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/shusunny/BART/runs/1v8evflt?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %% [markdown]
# Define `Seq2SeqTrainer` to compute the metrics from the predictions, and also do a bit of pre-processing to decode the predictions into texts:

# %%
# Define traing args, batch size and epoch
# batch size max 8 for input length 1024 on Colab Pro

batch_size = 4
epochs = 1
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-cnn",
    load_best_model_at_end="eval_loss",
    evaluation_strategy="steps",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    logging_steps=2500, 
    save_steps=5000,
    eval_steps=5000,
    save_total_limit=3,
    num_train_epochs=epochs,
    predict_with_generate=True,
    fp16=True,
    report_to="wandb",
)

# %%
import nltk
import numpy as np
nltk.download('punkt')

metric = datasets.load_metric("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# Pass into the trainer

train_dataset=tokenized_datasets["train"]
eval_dataset=tokenized_datasets["validation"].select(range(6684))

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using amp half precision backend

# %% [markdown]
# We can now finetune our model by just calling the `train` method:

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 287113
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 71779
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='39918' max='71779' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [39918/71779 5:54:09 < 4:42:41, 1.88 it/s, Epoch 0.56/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>2.150800</td>
#       <td>1.893104</td>
#       <td>23.526500</td>
#       <td>10.986600</td>
#       <td>19.473400</td>
#       <td>22.076600</td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.073500</td>
#       <td>1.840229</td>
#       <td>23.873000</td>
#       <td>11.451000</td>
#       <td>19.800600</td>
#       <td>22.446600</td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>2
td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>1.792500</td>
#       <td>1.633032</td>
#       <td>24.513200</td>
#       <td>12.077900</td>
#       <td>20.342100</td>
#       <td>23.036700</td>
#       <td>19.999700</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-40000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-40000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-40000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-40000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-40000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-25000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-45000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-45000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-45000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-45000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-45000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-30000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-50000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-50000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-50000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-50000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-50000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-35000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-55000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-55000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-55000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-55000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-55000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-40000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-60000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-60000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-60000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-60000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-60000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-45000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-65000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-65000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-65000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-65000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-65000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-50000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 6684
#   Batch size = 4
# Saving model checkpoint to bart-base-finetuned-cnn/checkpoint-70000
# Configuration saved in bart-base-finetuned-cnn/checkpoint-70000/config.json
# Model weights saved in bart-base-finetuned-cnn/checkpoint-70000/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-cnn/checkpoint-70000/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-cnn/checkpoint-70000/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-cnn/checkpoint-55000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bart-base-finetuned-cnn/checkpoint-70000 (score: 1.6330324411392212).
# TrainOutput(global_step=71779, training_loss=1.9352873979941905, metrics={'train_runtime': 39236.5177, 'train_samples_per_second': 7.317, 'train_steps_per_second': 1.829, 'total_flos': 1.6851518958403584e+17, 'train_loss': 1.9352873979941905, 'epoch': 1.0})

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 554... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>█████████████▁</td></tr><tr><td>eval/loss</td><td>█▇▆▅▅▄▄▃▃▂▂▂▁▁</td></tr><tr><td>eval/rouge1</td><td>▁▃▁▃▃▅▅▅▅▆▆█▆▇</td></tr><tr><td>eval/rouge2</td><td>▁▄▃▄▅▇▆▇▆▇▇█▇█</td></tr><tr><td>eval/rougeL</td><td>▁▃▁▄▄▆▆▆▆▆▇█▇█</td></tr><tr><td>eval/rougeLsum</td><td>▁▄▂▃▃▆▆▆▅▆▆█▇█</td></tr><tr><td>eval/runtime</td><td>▁█▅▅▃▄▁▂▂▂▁▂▂▁</td></tr><tr><td>eval/samples_per_second</td><td>▇▁▄▄▆▅█▇▇▇█▇▇█</td></tr><tr><td>eval/steps_per_second</td><td>█▁▄▄▆▅█▇▇▇█▇▇█</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/learning_rate</td><td>██▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>█▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>19.9997</td></tr><tr><td>eval/loss</td><td>1.63303</td></tr><tr><td>eval/rouge1</td><td>24.5132</td></tr><tr><td>eval/rouge2</td><td>12.0779</td></tr><tr><td>eval/rougeL</td><td>20.3421</td></tr><tr><td>eval/rougeLsum</td><td>23.0367</td></tr><tr><td>eval/runtime</td><td>974.6034</td></tr><tr><td>eval/samples_per_second</td><td>6.858</td></tr><tr><td>eval/steps_per_second</td><td>1.715</td></tr><tr><td>train/epoch</td><td>1.0</td></tr><tr><td>train/global_step</td><td>71779</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>1.7925</td></tr><tr><td>train/total_flos</td><td>1.6851518958403584e+17</td></tr><tr><td>train/train_loss</td><td>1.93529</td></tr><tr><td>train/train_runtime</td><td>39236.5177</td></tr><tr><td>train/train_samples_per_second</td><td>7.317</td></tr><tr><td>train/train_steps_per_second</td><td>1.829</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">sweet-fire-2</strong>: <a href="https://wandb.ai/shusunny/BART/runs/1v8evflt" target="_blank">https://wandb.ai/shusunny/BART/runs/1v8evflt</a><br/>
# Find logs at: <code>./wandb/run-20220216_190454-1v8evflt/logs</code><br/>

# %%
# !ls -lh
# Out:
# total 12K
# drwxr-xr-x 5 root root 4.0K Feb 17 05:51 bart-base-finetuned-cnn
# drwxr-xr-x 1 root root 4.0K Feb  1 14:32 sample_data
# drwxr-xr-x 3 root root 4.0K Feb 16 19:04 wandb

# %%
# !zip -r /content/bart-base-finetuned-cnn.zip /content/bart-base-finetuned-cnn/checkpoint-70000/
# Out:
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/ (stored 0%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/config.json (deflated 63%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/training_args.bin (deflated 49%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/trainer_state.json (deflated 80%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/scaler.pt (deflated 55%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/tokenizer_config.json (deflated 45%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/special_tokens_map.json (deflated 50%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/tokenizer.json (deflated 72%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/merges.txt (deflated 53%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/scheduler.pt (deflated 49%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/rng_state.pth (deflated 28%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/pytorch_model.bin (deflated 8%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/optimizer.pt (deflated 9%)
#   adding: content/bart-base-finetuned-cnn/checkpoint-70000/vocab.json (deflated 59%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp bart-base-finetuned-cnn.zip '/content/drive/My Drive/weights/'

# %% [markdown]
# ## Trying with a smaller dataset

# %%
# Select to get smaller dataset
small_train = raw_datasets['train'].select(list(range(0, 5000)))
small_val = raw_datasets['validation'].select(list(range(0, 500)))
small_train
# Out:
# Dataset({
#     features: ['document', 'summary', 'id'],
#     num_rows: 5000
# })

# %%
tokenized_train = small_train.map(preprocess_function, batched=True)
tokenized_val = small_val.map(preprocess_function, batched=True)
tokenized_train
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['attention_mask', 'document', 'id', 'input_ids', 'labels', 'summary'],
#     num_rows: 5000
# })

# %%
# Import original model in the cache
model_small = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
# Out:
# loading configuration file https://huggingface.co/facebook/bart-base/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/f5310d276a6d1648d00c32fadc8bf7b4607e0fbd5b404fc4a0045960aa2bdfdb.da0f3c0e2dc1c2fecc46738a1ebf4806f2fc36aae3d5c1947f21e063e7cab34b
# Model config BartConfig {
#   "_name_or_path": "bart-base",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.0,
#   "d_model": 768,
#   "decoder_attention_heads": 12,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 12,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 1024,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "length_penalty": 1.0,
#       "max_length": 128,
#       "min_length": 12,
#       "num_beams": 4
#     },
#     "summarization_cnn": {
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "num_beams": 4
#     },
#     "summarization_xsum": {
#       "length_penalty": 1.0,
#       "max_length": 62,
#       "min_length": 11,
#       "num_beams": 6
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.12.5",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file https://huggingface.co/facebook/bart-base/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/486355ec722ef05fd480e999d4c763be56549ae930f6a3742ee721a5d2a05647.f2f355ad2775769afc60592b43a46d72ca548375e3a1d65f381a751e711cbadd
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# All the weights of BartForConditionalGeneration were initialized from the model checkpoint at facebook/bart-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartForConditionalGeneration for predictions without further training.

# %%
# data collator: pad the inputs and labels during each batch to save space
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model_small)

# %%
# Define traing args, batch size and epoch
# batch size max 16 on Colab Pro

batch_size = 6
epochs = 40
model_name = model_checkpoint.split("/")[-1]
args_small = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-xsum-small",
    evaluation_strategy = "epoch",
    learning_rate=4e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_strategy = "epoch",
    save_total_limit=3,
    num_train_epochs=epochs,
    predict_with_generate=True,
    fp16=True,
    #push_to_hub=True,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Pass into the trainer

train_dataset=tokenized_train
eval_dataset=tokenized_val

trainer_small = Seq2SeqTrainer(
    model_small,
    args_small,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using amp fp16 backend

# %%
trainer_small.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running training *****
#   Num examples = 5000
#   Num Epochs = 40
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 1
#   Total optimization steps = 33360
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='12336' max='33360' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12336/33360 1:45:57 < 3:00:35, 1.94 it/s, Epoch 14.79/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2
special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-5004] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 6
# Saving model checkpoint to bart-base-finetuned-xsum-small/checkpoint-8340
# Configuration saved in bart-base-finetuned-xsum-small/checkpoint-8340/config.json
# Model weights saved in bart-base-finetuned-xsum-small/checkpoint-8340/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum-small/checkpoint-8340/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum-small/checkpoint-8340/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-5838] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 6
# Saving model checkpoint to bart-base-finetuned-xsum-small/checkpoint-9174
# Configuration saved in bart-base-finetuned-xsum-small/checkpoint-9174/config.json
# Model weights saved in bart-base-finetuned-xsum-small/checkpoint-9174/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum-small/checkpoint-9174/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum-small/checkpoint-9174/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-6672] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 6
# Saving model checkpoint to bart-base-finetuned-xsum-small/checkpoint-10008
# Configuration saved in bart-base-finetuned-xsum-small/checkpoint-10008/config.json
# Model weights saved in bart-base-finetuned-xsum-small/checkpoint-10008/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum-small/checkpoint-10008/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum-small/checkpoint-10008/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-7506] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 6
# Saving model checkpoint to bart-base-finetuned-xsum-small/checkpoint-10842
# Configuration saved in bart-base-finetuned-xsum-small/checkpoint-10842/config.json
# Model weights saved in bart-base-finetuned-xsum-small/checkpoint-10842/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum-small/checkpoint-10842/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum-small/checkpoint-10842/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-8340] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: summary, id, document.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 6
# Saving model checkpoint to bart-base-finetuned-xsum-small/checkpoint-11676
# Configuration saved in bart-base-finetuned-xsum-small/checkpoint-11676/config.json
# Model weights saved in bart-base-finetuned-xsum-small/checkpoint-11676/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum-small/checkpoint-11676/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum-small/checkpoint-11676/special_tokens_map.json
# Deleting older checkpoint [bart-base-finetuned-xsum-small/checkpoint-9174] due to args.save_total_limit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-800e0a84467d> in <module>()
# ----> 1 trainer_small.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1366                     elif self.use_amp:
#    1367                         scale_before = self.scaler.get_scale()
# -> 1368                         self.scaler.step(self.optimizer)
#    1369                         self.scaler.update()
#    1370                         scale_after = self.scaler.get_scale()
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/amp/grad_scaler.py in step(self, optimizer, *args, **kwargs)
#     336         assert len(optimizer_state["found_inf_per_device"]) > 0, "No inf checks were recorded for this optimizer."
#     337
# --> 338         retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     339
#     340         optimizer_state["stage"] = OptState.STEPPED
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/amp/grad_scaler.py in _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     283         retval = None
#     284         if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 285             retval = optimizer.step(*args, **kwargs)
#     286         return retval
#     287
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py in step(self, closure)
#     349                 exp_avg.mul_(beta1).add_(grad, alpha=(1.0 - beta1))
#     350                 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1.0 - beta2)
# --> 351                 denom = exp_avg_sq.sqrt().add_(group["eps"])
#     352
#     353                 step_size = group["lr"]
#
# KeyboardInterrupt:

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 3815... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>▂▅▁▆▃▅▄▆▃▇█▆▇▅</td></tr><tr><td>eval/loss</td><td>▁▁▂▂▃▄▅▅▆▆▇▇██</td></tr><tr><td>eval/rouge1</td><td>▄▆▇▆█▄▆▃▃▃▃▃▁▄</td></tr><tr><td>eval/rouge2</td><td>▆█▇▇▇▅▆▄▅▃▄▃▁▄</td></tr><tr><td>eval/rougeL</td><td>▅▆▇▅█▄▄▃▂▂▂▁▁▄</td></tr><tr><td>eval/rougeLsum</td><td>▅▆▇▅█▄▄▃▂▂▂▁▁▄</td></tr><tr><td>eval/runtime</td><td>▅▆▆▇▄▄▅▅▄▆█▁▂▂</td></tr><tr><td>eval/samples_per_second</td><td>▄▃▃▂▅▄▄▄▅▃▁█▇▇</td></tr><tr><td>eval/steps_per_second</td><td>▄▃▃▂▅▅▄▅▅▃▁█▇▇</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/learning_rate</td><td>██▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>█▇▆▆▆▅▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>19.72</td></tr><tr><td>eval/loss</td><td>3.18722</td></tr><tr><td>eval/rouge1</td><td>32.3288</td></tr><tr><td>eval/rouge2</td><td>11.3217</td></tr><tr><td>eval/rougeL</td><td>26.0661</td></tr><tr><td>eval/rougeLsum</td><td>26.0653</td></tr><tr><td>eval/runtime</td><td>47.2056</td></tr><tr><td>eval/samples_per_second</td><td>10.592</td></tr><tr><td>eval/steps_per_second</td><td>1.779</td></tr><tr><td>train/epoch</td><td>14.39</td></tr><tr><td>train/global_step</td><td>12000</td></tr><tr><td>train/learning_rate</td><td>3e-05</td></tr><tr><td>train/loss</td><td>0.1982</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">stellar-frost-2</strong>: <a href="https://wandb.ai/shusunny/BART-sum/runs/35vv83br" target="_blank">https://wandb.ai/shusunny/BART-sum/runs/35vv83br</a><br/>
# Find logs at: <code>./wandb/run-20211123_005148-35vv83br/logs</code><br/>
