# %% [markdown]
# ##Libraries and environment preparation

# %%
#Install essential packages
# %%capture
# !pip install datasets transformers rouge-score nltk wandb
# !apt install git-lfs

# %%
#Colab Environment Check for GPU and RAM
# !nvidia-smi
# Out:
# Wed Mar 30 18:07:07 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Make sure your version of Transformers is at least 4.11.0 
# to run the following code correctly:
import datasets
import transformers
print(transformers.__version__)
# Out:
# 4.17.0

# %%
from transformers import AutoTokenizer    
# Huggingface Automodel class
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

model_checkpoint = "facebook/bart-base"

# %%
# Import Wandb 
import os
import wandb
API_KEY = '39991c538626bee25c64d4f8a4c3403dd635537c'
os.environ["WANDB_API_KEY"] = API_KEY

# %% [markdown]
# ##Load the dataset

# %%
# import dataset
raw_datasets = datasets.load_dataset("xsum")
# Out:
# Downloading builder script:   0%|          | 0.00/2.05k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/954 [00:00<?, ?B/s]
# Using custom data configuration default
# Downloading and preparing dataset xsum/default (download: 245.38 MiB, generated: 507.60 MiB, post-processed: Unknown size, total: 752.98 MiB) to /root/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/204045 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11332 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11334 [00:00<?, ? examples/s]
# Dataset xsum downloaded and prepared to /root/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 204045
#     })
#     validation: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11332
#     })
#     test: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11334
#     })
# })

# %% [markdown]
# ##Preprocess the data

# %%
# Import tokenizer from model checkpoint
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
# tokenlize inputs into map

max_input_length = 512
max_target_length = 64

def preprocess_function(examples):
    inputs = [doc for doc in examples["document"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_train = raw_datasets["train"].map(preprocess_function, 
                                      batched=True,
                                      remove_columns=["document", "summary", "id"])
# Out:
#   0%|          | 0/205 [00:00<?, ?ba/s]

# %%
tokenized_val = raw_datasets["validation"].map(preprocess_function, 
                                      batched=True,
                                      remove_columns=["document", "summary", "id"])
# Out:
#   0%|          | 0/12 [00:00<?, ?ba/s]

# %%
tokenized_train
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 204045
# })

# %% [markdown]
# ##Fine-tuning the model

# %%
# Import tokenizer from model checkpoint and print detail
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

# data collator: pad the inputs and labels during each batch to save space
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
# Out:
# Downloading:   0%|          | 0.00/532M [00:00<?, ?B/s]

# %%
# Define traing args, batch size and epoch
# batch size max 8 for input length 1024 on Colab Pro

batch_size = 8
epochs = 1
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-xsum",
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_strategy = "epoch",
    save_total_limit=3,
    num_train_epochs=epochs,
    predict_with_generate=True,
    fp16=True,
    #report_to="wandb",
)

# %%
import nltk
import numpy as np
nltk.download('punkt')

metric = datasets.load_metric("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# Pass into the trainer

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 204045
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 25506
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: shusunny (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220330_181706-2ggul8tb</code>
# Syncing run <strong><a href="https://wandb.ai/shusunny/huggingface/runs/2ggul8tb" target="_blank">bart-base-finetuned-xsum</a></strong> to <a href="https://wandb.ai/shusunny/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='25506' max='25506' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25506/25506 2:40:35, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.990300</td>
#       <td>1.810514</td>
#       <td>37.314100</td>
#       <td>16.220800</td>
#       <td>30.857000</td>
#       <td>30.860600</td>
#       <td>19.568000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 11332
#   Batch size = 8
# Saving model checkpoint to bart-base-finetuned-xsum/checkpoint-25506
# Configuration saved in bart-base-finetuned-xsum/checkpoint-25506/config.json
# Model weights saved in bart-base-finetuned-xsum/checkpoint-25506/pytorch_model.bin
# tokenizer config file saved in bart-base-finetuned-xsum/checkpoint-25506/tokenizer_config.json
# Special tokens file saved in bart-base-finetuned-xsum/checkpoint-25506/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=25506, training_loss=2.1411598385861925, metrics={'train_runtime': 9641.5508, 'train_samples_per_second': 21.163, 'train_steps_per_second': 2.645, 'total_flos': 6.19560777378816e+16, 'train_loss': 2.1411598385861925, 'epoch': 1.0})

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/rouge1</td><td>▁</td></tr><tr><td>eval/rouge2</td><td>▁</td></tr><tr><td>eval/rougeL</td><td>▁</td></tr><tr><td>eval/rougeLsum</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>19.568</td></tr><tr><td>eval/loss</td><td>1.81051</td></tr><tr><td>eval/rouge1</td><td>37.3141</td></tr><tr><td>eval/rouge2</td><td>16.2208</td></tr><tr><td>eval/rougeL</td><td>30.857</td></tr><tr><td>eval/rougeLsum</td><td>30.8606</td></tr><tr><td>eval/runtime</td><td>723.858</td></tr><tr><td>eval/samples_per_second</td><td>15.655</td></tr><tr><td>eval/steps_per_second</td><td>1.958</td></tr><tr><td>train/epoch</td><td>1.0</td></tr><tr><td>train/global_step</td><td>25506</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>1.9903</td></tr><tr><td>train/total_flos</td><td>6.19560777378816e+16</td></tr><tr><td>train/train_loss</td><td>2.14116</td></tr><tr><td>train/train_runtime</td><td>9641.5508</td></tr><tr><td>train/train_samples_per_second</td><td>21.163</td></tr><tr><td>train/train_steps_per_second</td><td>2.645</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">bart-base-finetuned-xsum</strong>: <a href="https://wandb.ai/shusunny/huggingface/runs/2ggul8tb" target="_blank">https://wandb.ai/shusunny/huggingface/runs/2ggul8tb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220330_181706-2ggul8tb/logs</code>

# %%
# !ls -lh bart-base-finetuned-xsum
# Out:
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Mar 30 20:57 checkpoint-25506
# drwxr-xr-x 3 root root 4.0K Mar 30 18:17 runs

# %%
# !zip -r bart-base-finetuned-xsum.zip /content/bart-base-finetuned-xsum/checkpoint-25506/
# Out:
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/ (stored 0%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/scaler.pt (deflated 55%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/merges.txt (deflated 53%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/scheduler.pt (deflated 49%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/tokenizer_config.json (deflated 46%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/optimizer.pt (deflated 9%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/config.json (deflated 64%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/pytorch_model.bin (deflated 8%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/vocab.json (deflated 59%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/tokenizer.json (deflated 72%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/special_tokens_map.json (deflated 50%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/rng_state.pth (deflated 27%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/trainer_state.json (deflated 79%)
#   adding: content/bart-base-finetuned-xsum/checkpoint-25506/training_args.bin (deflated 49%)

# %%
# !cp bart-base-finetuned-xsum.zip '/content/drive/My Drive/weights/'
