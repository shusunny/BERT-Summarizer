# %% [markdown]
# # Fine-tune Prophetnet on Xsum smallset

# %% [markdown]
# ##Libraries and environment preparation

# %%
#Install essential packages
# %%capture
# !pip install datasets transformers rouge-score nltk wandb
# !apt install git-lfs

# %%
#Colab Environment Check for GPU and RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

#GPU check
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Thu Mar  3 19:48:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Make sure your version of Transformers is at least 4.11.0 
# to run the following code correctly:
import datasets
import transformers
print(transformers.__version__)
# Out:
# 4.17.0

# %%
from transformers import AutoTokenizer    
# Huggingface Automodel class
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

model_checkpoint = "microsoft/prophetnet-large-uncased"

# %%
# Import Wandb 
import os
import wandb
API_KEY = '39991c538626bee25c64d4f8a4c3403dd635537c'
os.environ["WANDB_API_KEY"] = API_KEY

# %% [markdown]
# ##Load the dataset

# %%
# import dataset
raw_datasets = datasets.load_dataset("xsum")
# Out:
# Downloading:   0%|          | 0.00/2.05k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/954 [00:00<?, ?B/s]
# Using custom data configuration default
# Downloading and preparing dataset xsum/default (download: 245.38 MiB, generated: 507.60 MiB, post-processed: Unknown size, total: 752.98 MiB) to /root/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset xsum downloaded and prepared to /root/.cache/huggingface/datasets/xsum/default/1.2.0/32c23220eadddb1149b16ed2e9430a05293768cfffbdfd151058697d4c11f934. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 204045
#     })
#     validation: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11332
#     })
#     test: Dataset({
#         features: ['document', 'summary', 'id'],
#         num_rows: 11334
#     })
# })

# %% [markdown]
# ##Preprocess the data

# %%
# Import tokenizer from model checkpoint
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/141 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:357: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]

# %%
# tokenlize inputs into map

max_input_length = 512
max_target_length = 64

def preprocess_function(examples):
    inputs = [doc for doc in examples["document"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["summary"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_train = raw_datasets["train"].select(range(10000)).map(preprocess_function, 
                                      batched=True,
                                      remove_columns=["document", "summary", "id"])
# Out:
#   0%|          | 0/10 [00:00<?, ?ba/s]

# %%
tokenized_val = raw_datasets["validation"].select(range(1000)).map(preprocess_function, 
                                      batched=True,
                                      remove_columns=["document", "summary", "id"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_train
# Out:
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 10000
# })

# %% [markdown]
# ##Fine-tuning the model

# %%
# Import tokenizer from model checkpoint and print detail
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint, use_cache=False)

# data collator: pad the inputs and labels during each batch to save space
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:357: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/1.46G [00:00<?, ?B/s]

# %%
wandb.init(project="prophetnet")
# Out:
# wandb: Currently logged in as: shusunny (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220303_195345-2bq30zwa</code>
# Syncing run <strong><a href="https://wandb.ai/shusunny/prophetnet/runs/2bq30zwa" target="_blank">swift-voice-3</a></strong> to <a href="https://wandb.ai/shusunny/prophetnet" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/shusunny/prophetnet/runs/2bq30zwa?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# Define traing args, batch size and epoch
# batch size max 8 for input length 1024 on Colab Pro

batch_size = 4
epochs = 10
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-xsum",
    load_best_model_at_end="eval_loss",
    evaluation_strategy="steps",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    logging_steps=1000, 
    save_steps=2500,
    eval_steps=2500,
    save_total_limit=3,
    num_train_epochs=epochs,
    predict_with_generate=True,
    fp16=True,
    report_to="wandb",
)

# %%
import nltk
import numpy as np
nltk.download('punkt')

metric = datasets.load_metric("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
# Pass into the trainer

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 10000
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 25000
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='25000' max='25000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25000/25000 9:30:19, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2500</td>
#       <td>3.149100</td>
#       <td>2.862716</td>
#       <td>34.530400</td>
#       <td>12.512200</td>
#       <td>27.192300</td>
#       <td>27.245500</td>
#       <td>26.276000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.456800</td>
#       <td>2.861875</td>
#       <td>35.853800</td>
#       <td>13.414500</td>
#       <td>28.671600</td>
#       <td>28.716100</td>
#       <td>26.518000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.903700</td>
#       <td>2.979194</td>
#       <td>36.051500</td>
#       <td>13.492400</td>
#       <td>28.519300</td>
#       <td>28.562900</td>
#       <td>25.911000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.465700</td>
#       <td>3.076283</td>
#       <td>35.811700</td>
#       <td>13.248300</td>
#       <td>28.461900</td>
#       <td>28.514500</td>
#       <td>27.842000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.032900</td>
#       <td>3.234437</td>
#       <td>35.543500</td>
#       <td>13.036400</td>
#       <td>28.185600</td>
#       <td>28.226500</td>
#       <td>28.083000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.738100</td>
#       <td>3.397255</td>
#       <td>35.599500</td>
#       <td>13.337100</td>
#       <td>28.208700</td>
#       <td>28.303200</td>
#       <td>27.374000</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.517000</td>
#       <td>3.523091</td>
#       <td>35.929800</td>
#       <td>13.068400</td>
#       <td>28.366900</td>
#       <td>28.408500</td>
#       <td>27.550000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.342500</td>
#       <td>3.665251</td>
#       <td>36.105100</td>
#       <td>13.202200</td>
#       <td>28.572700</td>
#       <td>28.635500</td>
#       <td>27.135000</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.251500</td>
#       <td>3.782606</td>
#       <td>36.528600</td>
#       <td>13.180700</td>
#       <td>28.945500</td>
#       <td>29.012100</td>
#       <td>27.412000</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.184600</td>
#       <td>3.850682</td>
#       <td>36.470500</td>
#       <td>13.371100</td>
#       <td>29.014600</td>
#       <td>29.078700</td>
#       <td>27.317000</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-2500
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-2500/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-5000
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-5000/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-5000/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-7500
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-7500/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-7500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-10000
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-10000/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-12500
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-12500/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-7500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-15000
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-15000/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-15000/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-17500
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-17500/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-17500/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-12500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-20000
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-20000/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-20000/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-15000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-22500
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-22500/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-22500/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-17500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `ProphetNetForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `ProphetNetForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 4
# Saving model checkpoint to prophetnet-large-uncased-finetuned-xsum/checkpoint-25000
# Configuration saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/config.json
# Model weights saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/special_tokens_map.json
# Deleting older checkpoint [prophetnet-large-uncased-finetuned-xsum/checkpoint-20000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from prophetnet-large-uncased-finetuned-xsum/checkpoint-5000 (score: 2.861875057220459).
# TrainOutput(global_step=25000, training_loss=1.194938226928711, metrics={'train_runtime': 34220.9896, 'train_samples_per_second': 2.922, 'train_steps_per_second': 0.731, 'total_flos': 1.0595649557692416e+17, 'train_loss': 1.194938226928711, 'epoch': 10.0})

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>▂▃▁▇█▆▆▅▆▆</td></tr><tr><td>eval/loss</td><td>▁▁▂▃▄▅▆▇██</td></tr><tr><td>eval/rouge1</td><td>▁▆▆▅▅▅▆▇██</td></tr><tr><td>eval/rouge2</td><td>▁▇█▆▅▇▅▆▆▇</td></tr><tr><td>eval/rougeL</td><td>▁▇▆▆▅▅▆▆██</td></tr><tr><td>eval/rougeLsum</td><td>▁▇▆▆▅▅▅▆██</td></tr><tr><td>eval/runtime</td><td>▁▂▁▆█▄▅▄▅▄</td></tr><tr><td>eval/samples_per_second</td><td>█▆█▂▁▅▄▅▄▄</td></tr><tr><td>eval/steps_per_second</td><td>█▆█▂▁▅▄▅▄▄</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>██▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▂▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>██▇▆▆▅▅▄▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/gen_len</td><td>27.317</td></tr><tr><td>eval/loss</td><td>3.85068</td></tr><tr><td>eval/rouge1</td><td>36.4705</td></tr><tr><td>eval/rouge2</td><td>13.3711</td></tr><tr><td>eval/rougeL</td><td>29.0146</td></tr><tr><td>eval/rougeLsum</td><td>29.0787</td></tr><tr><td>eval/runtime</td><td>1276.074</td></tr><tr><td>eval/samples_per_second</td><td>0.784</td></tr><tr><td>eval/steps_per_second</td><td>0.196</td></tr><tr><td>train/epoch</td><td>10.0</td></tr><tr><td>train/global_step</td><td>25000</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.1846</td></tr><tr><td>train/total_flos</td><td>1.0595649557692416e+17</td></tr><tr><td>train/train_loss</td><td>1.19494</td></tr><tr><td>train/train_runtime</td><td>34220.9896</td></tr><tr><td>train/train_samples_per_second</td><td>2.922</td></tr><tr><td>train/train_steps_per_second</td><td>0.731</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">swift-voice-3</strong>: <a href="https://wandb.ai/shusunny/prophetnet/runs/2bq30zwa" target="_blank">https://wandb.ai/shusunny/prophetnet/runs/2bq30zwa</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220303_195345-2bq30zwa/logs</code>

# %%
model.config
# Out:
# ProphetNetConfig {
#   "_name_or_path": "microsoft/prophetnet-large-uncased",
#   "activation_dropout": 0.1,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ProphetNetForConditionalGeneration"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 102,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_max_position_embeddings": 514,
#   "decoder_start_token_id": 102,
#   "disable_ngram_loss": false,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_max_position_embeddings": 513,
#   "eos_token_id": 102,
#   "eps": 0.0,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 512,
#   "model_type": "prophetnet",
#   "ngram": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "num_buckets": 32,
#   "num_decoder_attention_heads": 16,
#   "num_decoder_layers": 12,
#   "num_encoder_attention_heads": 16,
#   "num_encoder_layers": 12,
#   "output_past": false,
#   "pad_token_id": 0,
#   "prefix": " ",
#   "relative_max_distance": 128,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "use_cache": false,
#   "vocab_size": 30522
# }

# %%
# !ls -lh
# Out:
# total 4.0G
# drwx------ 5 root root 4.0K Feb 22 18:17 drive
# drwxr-xr-x 5 root root 4.0K Feb 23 06:28 prophetnet-large-uncased-finetuned-xsum
# -rw-r--r-- 1 root root 4.0G Feb 23 06:34 prophetnet-large-uncased-finetuned-xsum.zip
# drwxr-xr-x 1 root root 4.0K Feb 18 14:33 sample_data
# drwxr-xr-x 3 root root 4.0K Feb 22 18:43 wandb

# %%
# !zip -r /content/prophetnet-large-uncased-finetuned-xsum.zip /content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/
# Out:
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/ (stored 0%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/special_tokens_map.json (deflated 37%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/pytorch_model.bin (deflated 7%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/optimizer.pt (deflated 9%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/config.json (deflated 60%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/trainer_state.json (deflated 80%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/rng_state.pth (deflated 27%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/tokenizer_config.json (deflated 40%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/scheduler.pt (deflated 49%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/training_args.bin (deflated 48%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/scaler.pt (deflated 55%)
#   adding: content/prophetnet-large-uncased-finetuned-xsum/checkpoint-25000/prophetnet.tokenizer (deflated 53%)

# %%
# !cp prophetnet-large-uncased-finetuned-xsum.zip '/content/drive/My Drive/weights/'
